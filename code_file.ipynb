# %% [markdown]
# # Data extraction

# %%
# Importing necessary libraries
from bs4 import BeautifulSoup
import pandas as pd
import requests, os
from time import time
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
start = time()
# Open the file input.xlsx and iterate through each row
file = pd.read_excel('input.xlsx')

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL_ID  114 non-null    int64
#  1   URL     114 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 1.9+ KB

# %%
for index, row in file.iterrows():
    URL_ID, URL = row['URL_ID'], row['URL']
    # Get the response from the URL
    resp = requests.get(URL, timeout=5)
    if resp.status_code != 200:
        print(f'Error for URL_ID: {URL_ID} with status code: {resp.status_code}')
        continue
    
    # Parse the response using BeautifulSoup
    soup = BeautifulSoup(resp.content, 'html.parser')
    
    # Get the h1 of the article
    title = soup.find('h1').text.strip()
    # print(f'Title: {title}')
    
    # Find the main article text in the <div> tag with class 'tdb-block-inner td-fix-index' with all the <p> tags
    
    article_text = ''
    for p in soup.find_all('p'):
        # check if the <p> tag is inside the <div> tag with class 'tdb-block-inner td-fix-index' or 'td-post-content tagdiv-type'
        if p.parent.name == 'div':
            if p.parent.get('class') == ['tdb-block-inner', 'td-fix-index'] or p.parent.get('class') == ['td-post-content', 'tagdiv-type']:
                article_text += p.text.strip() + '\n'
        
    # print(f'Article Text: {article_text}')
    print(f'URL_ID: {URL_ID}, words: {len(article_text.split())}')
        
    # create directory 'articles' if it doesn't exist
    if not os.path.exists('articles'):
        os.makedirs('articles')
    # save the article text in a file with the name as URL_ID
    with open(f'articles/{URL_ID}.txt', 'w', encoding='utf-8') as file:
        file.write(f'Title: {title}\n\n{article_text}')
        print('txt file created with URL ID:',title)
    

# Time taken in minutes
print(f'Time taken: {(time() - start) / 60} min')
# Out:
# URL_ID: 37, words: 1773
# txt file created with URL ID: AI in healthcare to Improve Patient Outcomes
# URL_ID: 38, words: 1401
# txt file created with URL ID: What if the Creation is Taking Over the Creator?
# URL_ID: 39, words: 1684
# txt file created with URL ID: What Jobs Will Robots Take From Humans in The Future?
# URL_ID: 40, words: 1588
# txt file created with URL ID: Will Machine Replace The Human in the Future of Work?
# URL_ID: 41, words: 1690
# txt file created with URL ID: Will AI Replace Us or Work With Us?
# URL_ID: 42, words: 1232
# txt file created with URL ID: Will machine replace the human in the future of work?
# URL_ID: 43, words: 726
# txt file created with URL ID: How humans and machines are evolving to work together?
# Error for URL_ID: 44 with status code: 404
# URL_ID: 45, words: 698
# txt file created with URL ID: How machine learning will affect your business?
# URL_ID: 46, words: 2148
# txt file created with URL ID: Deep learning impact on areas of e-learning?
# URL_ID: 47, words: 1835
# txt file created with URL ID: How to protect future data and its privacy?
# URL_ID: 48, words: 1170
# txt file created with URL ID: How Machines, AI, Automations, and Robo-human are Effective in Finance and Banking?
# URL_ID: 49, words: 1207
# txt file created with URL ID: How Robo Human will Impact the Future?
# URL_ID: 50, words: 1643
# txt file created with URL ID: How AI will change the World?
# URL_ID: 51, words: 1529
# txt file created with URL ID: Future of Work: How AI Has Entered the Workplace
# URL_ID: 52, words: 499
# txt file created with URL ID: How machine learning used in finance and banking?
# URL_ID: 53, words: 1797
# txt file created with URL ID: How AI will impact the future of work?
# URL_ID: 54, words: 745
# txt file created with URL ID: All you need to know about online marketing
# URL_ID: 55, words: 701
# txt file created with URL ID: Evolution of Advertising Industry
# URL_ID: 56, words: 169
# txt file created with URL ID: How Data Analytics can help your business respond to the impact of COVID-19?
# Error for URL_ID: 57 with status code: 404
# URL_ID: 58, words: 1366
# txt file created with URL ID: Environmental impact of the COVID-19 pandemic – Lesson for the Future
# URL_ID: 59, words: 713
# txt file created with URL ID: How Data Analytics and AI are used to halt the COVID-19 Pandemic?
# URL_ID: 60, words: 1887
# txt file created with URL ID: What is the difference between Artificial Intelligence, Machine Learning, Statistics, and Data Mining?
# URL_ID: 61, words: 647
# txt file created with URL ID: How Python became the first choice for Data Science.
# URL_ID: 62, words: 365
# txt file created with URL ID: How Google fit measure heart and respiratory rates using a phone camera?
# URL_ID: 63, words: 802
# txt file created with URL ID: What is the future of mobile apps?
# URL_ID: 64, words: 465
# txt file created with URL ID: Impact of AI in health and medicine
# URL_ID: 65, words: 377
# txt file created with URL ID: What patients like and dislike about telemedicine?
# URL_ID: 66, words: 153
# txt file created with URL ID: How we forecast future technologies?
# URL_ID: 67, words: 799
# txt file created with URL ID: Can robots tackle late-life loneliness?
# URL_ID: 68, words: 176
# txt file created with URL ID: Embedding care robots into society and practice: Socio-technical considerations
# URL_ID: 69, words: 671
# txt file created with URL ID: Management challenges for future digitalization of healthcare services
# URL_ID: 70, words: 145
# txt file created with URL ID: Are we any closer to preventing a nuclear holocaust?
# URL_ID: 71, words: 373
# txt file created with URL ID: Will technology eliminate the need for animal testing in drug development?
# URL_ID: 72, words: 1709
# txt file created with URL ID: Will we ever understand the nature of consciousness?
# URL_ID: 73, words: 1741
# txt file created with URL ID: Will we ever colonize outer space?
# URL_ID: 74, words: 1444
# txt file created with URL ID: What is the chance Homo sapiens will survive for the next 500 years?
# URL_ID: 75, words: 855
# txt file created with URL ID: Why does your business need a chatbot?
# URL_ID: 76, words: 1400
# txt file created with URL ID: How you lead a project or a team without any technical expertise?
# URL_ID: 77, words: 461
# txt file created with URL ID: Can You Be Great Leader Without Technical Expertise
# URL_ID: 78, words: 1581
# txt file created with URL ID: How does artificial intelligence affect the environment
# URL_ID: 79, words: 978
# txt file created with URL ID: How to Overcome Your Fear of Making Mistakes
# URL_ID: 80, words: 1116
# txt file created with URL ID: Is Perfection the Greatest enemy of Productivity?
# URL_ID: 81, words: 1012
# txt file created with URL ID: Global financial crisis 2008 causes/effects and its solution
# URL_ID: 82, words: 1071
# txt file created with URL ID: Gender diversity and Equality in the tech industry
# URL_ID: 83, words: 1003
# txt file created with URL ID: How to overcome your fear of making mistakes?
# URL_ID: 84, words: 666
# txt file created with URL ID: How Small Business can survive the Coronavirus Crisis
# URL_ID: 85, words: 289
# txt file created with URL ID: Impacts of COVID 19 on Food products
# URL_ID: 86, words: 732
# txt file created with URL ID: Impacts of COVID 19 on Vegetable Vendors
# URL_ID: 87, words: 1203
# txt file created with URL ID: Impact of COVID-19 pandemic on Tourism & Aviation industries
# URL_ID: 120, words: 2134
# txt file created with URL ID: Why scams like Nirav Modi Happen with Indian banks?
# URL_ID: 121, words: 1591
# txt file created with URL ID: IMPACT OF COVID-19 ON THE GLOBAL ECONOMY
# URL_ID: 122, words: 1694
# txt file created with URL ID: Impact of coronavirus on the Indian economy
# URL_ID: 123, words: 1800
# txt file created with URL ID: Global Economy effected by Coronavirus
# URL_ID: 124, words: 999
# txt file created with URL ID: Impact of COVID-19 (Coronavirus) on the Indian Economy
# URL_ID: 125, words: 1821
# txt file created with URL ID: Should celebrities be allowed to join politics?
# URL_ID: 126, words: 833
# txt file created with URL ID: How prepared is India to tackle a possible COVID-19 outbreak?
# URL_ID: 127, words: 1317
# txt file created with URL ID: How will COVID-19 affect the world of work?
# URL_ID: 128, words: 286
# txt file created with URL ID: Controversy as a Marketing Strategy
# URL_ID: 129, words: 468
# txt file created with URL ID: Coronavirus: Impact on the Hospitality Industry
# URL_ID: 130, words: 1664
# txt file created with URL ID: Coronavirus impact on energy markets
# URL_ID: 131, words: 1658
# txt file created with URL ID: What are the key policies that will mitigate the impacts of COVID-19 on the world of work?
# URL_ID: 132, words: 1342
# txt file created with URL ID: Marketing Drives Results With A Focus On Problems
# URL_ID: 133, words: 661
# txt file created with URL ID: Continued Demand for Sustainability
# URL_ID: 134, words: 309
# txt file created with URL ID: Coronavirus Disease (COVID-19) Effect: The Impact and Role of Mass Media During the Pandemic
# URL_ID: 135, words: 318
# txt file created with URL ID: Should people wear fabric gloves? Seeking evidence regarding the differential transfer of COVID-19 (or coronaviruses generally) between surfaces?
# URL_ID: 136, words: 390
# txt file created with URL ID: Why is there a severe immunological and inflammatory explosion in those affected by sarms covid-19?
# URL_ID: 137, words: 222
# txt file created with URL ID: What do you think is the lesson (or lessons) to be learned with Covid 19?
# URL_ID: 138, words: 251
# txt file created with URL ID: Coronavirus, the unexpected challenge for the European union
# URL_ID: 139, words: 153
# txt file created with URL ID: INDUSTRIAL REVOLUTION 4.0 – PROS AND CONS
# URL_ID: 140, words: 927
# txt file created with URL ID: COVID-19 Vs Indian Economy
# URL_ID: 141, words: 462
# txt file created with URL ID: Impact of COVID-19 (Coronavirus) on the Indian Economy
# URL_ID: 142, words: 1807
# txt file created with URL ID: Impact of Indian Economy due to COVID-19
# URL_ID: 143, words: 604
# txt file created with URL ID: Impact of newly discovered coronavirus on the Global Economy
# Error for URL_ID: 144 with status code: 404
# URL_ID: 145, words: 724
# txt file created with URL ID: Blockchain in Fintech
# URL_ID: 146, words: 886
# txt file created with URL ID: Blockchain for Payments
# URL_ID: 147, words: 1092
# txt file created with URL ID: The future of Investing
# URL_ID: 148, words: 1122
# txt file created with URL ID: Big Data Analytics in Healthcare
# URL_ID: 149, words: 559
# txt file created with URL ID: Business Analytics In The Healthcare Industry
# URL_ID: 150, words: 1029
# txt file created with URL ID: Challenges and Opportunities of Big Data in Healthcare
# Time taken: 6.193296043078105 min

# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import nltk
import spacy
from textblob import TextBlob
import pyphen
import statistics

# Load the input data
input_data = pd.read_excel("input.xlsx")

# Perform text analysis
for index, row in input_data.iterrows():
    try:
        url_id = row["URL_ID"]
        file_path = f"articles/{url_id}.txt"
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()

        # Positive score
        positive_score = TextBlob(text).sentiment.polarity
        input_data.at[index, "Positive Score"] = positive_score

        # Negative score
        negative_score = TextBlob(text).sentiment.subjectivity
        input_data.at[index, "Negative Score"] = negative_score

        # Polarity score
        polarity_score = TextBlob(text).sentiment.polarity
        input_data.at[index, "Polarity Score"] = polarity_score

        # Subjectivity score
        subjectivity_score = TextBlob(text).sentiment.subjectivity
        input_data.at[index, "Subjectivity Score"] = subjectivity_score

        # Average sentence length
        sentence_lengths = [len(sentence) for sentence in nltk.sent_tokenize(text)]
        average_sentence_length = statistics.mean(sentence_lengths)
        input_data.at[index, "Average Sentence Length"] = average_sentence_length

        # Tokenize the text
        tokens = nltk.word_tokenize(text)

        # Percentage of complex words
        percentage_of_complex_words = len(nltk.pos_tag(tokens)) / len(tokens)
        input_data.at[index, "Percentage of Complex Words"] = percentage_of_complex_words

        # Fog index
        fog_index = (20 * (1 + (percentage_of_complex_words / 5))) - (1.8 * average_sentence_length)
        input_data.at[index, "Fog Index"] = fog_index

        # Average number of words per sentence
        average_number_of_words_per_sentence = len(tokens) / len(nltk.sent_tokenize(text))
        input_data.at[index, "Average Number of Words Per Sentence"] = average_number_of_words_per_sentence

        # Complex word count
        complex_word_count = len(nltk.pos_tag(tokens))
        input_data.at[index, "Complex Word Count"] = complex_word_count

        # Word count
        word_count = len(tokens)
        input_data.at[index, "Word Count"] = word_count

        # Syllable per word
        dic = pyphen.Pyphen(lang='en')
        syllable_count = 0
        word_count = 0

        for word in tokens:
            syllables = dic.inserted(word).count('-') + 1
            syllable_count += syllables
            word_count += 1

        syllable_per_word = syllable_count / word_count
        input_data.at[index, "Syllable per word"] = syllable_per_word

        # Personal pronouns
        nlp = spacy.load('en_core_web_sm')
        doc = nlp(text)
        personal_pronouns = 0

        for token in doc:
            if token.pos_ == 'PRON' and token.text.lower() in ['i', 'me', 'my', 'mine', 'myself', 'you', 'your', 'yours', 'yourself']:
                personal_pronouns += 1

        input_data.at[index, "Personal Pronouns"] = personal_pronouns

        # Average word length
        average_word_length = sum(len(word) for word in tokens) / len(tokens)
        input_data.at[index, "Average Word Length"] = average_word_length

    except FileNotFoundError:
        print(f"File not found for URL ID: {url_id}. Skipping iteration.")
# Out:
# File not found for URL ID: 44. Skipping iteration.
# File not found for URL ID: 57. Skipping iteration.
# File not found for URL ID: 144. Skipping iteration.

# %%
# Write the output data to an Excel file
output_data = input_data[["URL_ID", "Positive Score", "Negative Score", "Polarity Score",
                          "Subjectivity Score", "Average Sentence Length", "Percentage of Complex Words", "Fog Index",
                          "Average Number of Words Per Sentence", "Complex Word Count", "Word Count", "Syllable per word",
                          "Personal Pronouns", "Average Word Length"]]
output_data.to_excel("output_file.xlsx", index=False)
